# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('trial_sequences/test/trial_sequence_s000.csv')#.type.value_counts()
# Out:
#    type  iti_s  iti_TR  cond_frames  cond_ms  texture_id
# 0   dur   5.28     4.0            0      0.0           0
# 1   dur  14.52    11.0           16    134.0           1
# 2   isi   5.28     4.0           16    134.0           2
# 3   isi   6.60     5.0           64    533.0           3
# 4   isi  10.56     8.0            8     67.0           4
# 5   isi   3.96     3.0           32    267.0           5
# 6   isi   5.28     4.0           32    267.0           6
# 7   isi   3.96     3.0            4     33.0           7
# 8   dur   3.96     3.0           16    134.0           8
# 9   dur   9.24     7.0           64    533.0           9
# 10  dur  10.56     8.0           64    533.0          10
# 11  dur   9.24     7.0            2     17.0          11
# 12  dur   3.96     3.0            4     33.0          12
# 13  isi  17.16    13.0           16    134.0          13
# 14  dur  15.84    12.0            4     33.0          14
# ...

# %%
import random

reps = 5
total_trials = 79

trial_type = ['dur'] * 7 + ['isi'] * 6
trial_type = trial_type * 5
trial_cond_frames = [0, 2, 4, 8, 16, 32, 64, 2, 4, 8, 16, 32, 64]
trial_cond_frames = trial_cond_frames * 5

type_cond_list = list(zip(trial_type, trial_cond_frames))

# add blanks
n_blanks = total_trials - len(type_cond_list)
blank_trials = [('dur', 0)] * n_blanks

type_cond_list = type_cond_list + blank_trials

random.shuffle(type_cond_list)
seq_df = pd.DataFrame(type_cond_list, columns = ['type', 'cond_frames'])
seq_df['iti_TR'] = 3.0
seq_df['iti_s'] = 3.0 * 1.32
seq_df['cond_ms'] = seq_df['cond_frames'] / 120 * 1000

seq_df.iti_s.sum()
# Out:
# 312.83999999999986

# %%
79 * 1.32 * 3
# Out:
# 312.84000000000003

# %%
trial_cond_frames
# Out:
# [0,
#  2,
#  4,
#  8,
#  16,
#  32,
#  64,
#  2,
#  4,
#  8,
#  16,
#  32,
#  64,
#  0,
#  2,
#  4,
#  8,
#  16,
#  32,
#  64,
#  2,
#  4,
#  8,
#  16,
#  32,
#  64,
#  0,
#  2,
#  4,
#  8,
#  16,
#  32,
#  64,
#  2,
#  4,
#  8,
#  16,
#  32,
#  64,
#  0,
#  2,
#  4,
#  8,
#  16,
#  32,
#  64,
#  2,
#  4,
#  8,
#  16,
#  32,
#  64,
#  0,
#  2,
#  4,
#  8,
#  16,
#  32,
#  64,
#  2,
#  4,
#  8,
#  16,
#  32,
#  64]
